# %% [markdown]
# Import Datasets:
#
# 2018 EV Station Data : `mongoimport --type json -d team_1_db -c ev_stations_2018 --drop  washington_2018.01.31.geojson`
# 2022 EV Station Data: `mongoimport --type json -d team_1_db -c ev_stations_2022 --drop  washington_2022.01.31.geojson`

# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# confirm that our new database was created
print(mongo.list_database_names())
# Out:
# ['admin', 'autosaurus', 'classDB', 'config', 'epa', 'fruits_db', 'garden_db', 'local', 'met', 'petsitly_marketing', 'team_1_db', 'travel_db', 'uk_food']

# %%
# assign the uk_food database to a variable name
db = mongo['team_1_db']

# %%
# review the collections in our new database
db.list_collection_names()
# Out:
# ['ev_stations_2018', 'ev_stations_2022']

# %%
# review the collections in our new database
pprint(db.ev_stations_2018.find_one())
# Out:
# {'_id': ObjectId('65fa6240767ec832cf373452'),
#  'features': [{'geometry': {'coordinates': [-122.823144, 47.044015],
#                             'type': 'Point'},
#                'properties': {'access_code': 'public',
#                               'access_days_time': '24 hours daily',
#                               'access_days_time_fr': None,
#                               'access_detail_code': None,
#                               'bd_blends': None,
#                               'bd_blends_fr': None,
#                               'cards_accepted': None,
#                               'city': 'Lacey',
#                               'cng_dispenser_num': None,
#                               'cng_fill_type_code': None,
#                               'cng_has_rng': None,
#                               'cng_psi': None,
#                               'cng_renewable_source': None,
#                               'cng_total_compression': None,
# ...
